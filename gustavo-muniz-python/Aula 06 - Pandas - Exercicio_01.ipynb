# %% [markdown]
# ### Exercício 01 – Manipulando dataframes com Pandas.
#         a) Abra o arquivo world_happiness_report_2015.csv e o aloque em um dataframe.
#         b) Verifique o cabeçalho e o final do dataframe.
#         c) Quais as colunas desse dataframe?
#         d) Quais os tipos de dados temos no dataframe?
#         e) Há valores faltantes ou nulos? Em quais colunas?
#         f) Renomeie as variáveis como segue:

# %%
import pandas as pd 

caminho = ("C:\\Users\\FIC\\Documents\\gustavo-muniz-python\\Arquivos\\world_happiness_report_2015.csv")

df = pd.read_csv (caminho)

df.head(2)
# Out:
#        country          region  happiness rank  happiness score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    standard error  economy (GDP per Capita)   family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    health (Life Expectancy)  freedom  trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    generosity  dystopia residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
df.tail(1)
# Out:
#     country              region  happiness rank  happiness score  \
# 163    Togo  Sub-Saharan Africa             158            2.839
#
#      standard error  economy (GDP per Capita)   family  \
# 163         0.06727                   0.20868  0.13995
#
#      health (Life Expectancy)  freedom  trust (Government Corruption)  \
# 163                   0.28443  0.36453                        0.10731
#
#      generosity  dystopia residual
# 163     0.16681                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        164 non-null    object
#  1   region                         164 non-null    object
#  2   happiness rank                 164 non-null    int64
#  3   happiness score                156 non-null    float64
#  4   standard error                 163 non-null    float64
#  5   economy (GDP per Capita)       164 non-null    float64
#  6   family                         164 non-null    float64
#  7   health (Life Expectancy)       164 non-null    float64
#  8   freedom                        164 non-null    float64
#  9   trust (Government Corruption)  164 non-null    float64
#  10  generosity                     164 non-null    float64
#  11  dystopia residual              150 non-null    float64
# ...

# %%
df = df.rename(columns={
    'happiness rank':'rank_felicidade',
    'hapiness score': 'score_felicidade',
    'standart error':'stand_error',
    'economy (GDP per Capita)': 'PIB',
    'health (Life Expectancy)':'expect_vida',
    'trust (Government Corruption)':'corrupcao'
})

df.head()
# Out:
#        country          region  rank_felicidade  happiness score  \
# 0  Switzerland  Western Europe                1            7.587
# 1      Iceland  Western Europe                2            7.561
# 2      Denmark  Western Europe                3            7.527
# 3       Norway  Western Europe                4            7.522
# 4       Canada   North America                5            7.427
#
#    standard error      PIB   family  expect_vida  freedom  corrupcao  \
# 0         0.03411  1.39651  1.34951      0.94143  0.66557    0.41978
# 1         0.04884  1.30232  1.40223      0.94784  0.62877    0.14145
# 2         0.03328  1.32548  1.36058      0.87464  0.64938    0.48357
# 3         0.03880  1.45900  1.33095      0.88521  0.66973    0.36503
# 4         0.03553  1.32629  1.32261      0.90563  0.63297    0.32957
#
#    generosity  dystopia residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# ...

# %% [markdown]
# ### Respostas
#
# D - Temos : STR, Inteiro e Float
#
# E - Sim, temos valores faltntes. Na coluna "happiness score" temos 156, "standard error" temos 163 e "dystopia residual" temos 150. Não temos valores nulos.

# %%
df.describe(include='all')
# Out:
#           country              region  rank_felicidade  happiness score  \
# count         164                 164       164.000000       156.000000
# unique        158                  10              NaN              NaN
# top     Venezuela  Sub-Saharan Africa              NaN              NaN
# freq            2                  40              NaN              NaN
# mean          NaN                 NaN        77.018293         5.424487
# std           NaN                 NaN        46.699860         1.212568
# min           NaN                 NaN         1.000000         2.000000
# 25%           NaN                 NaN        35.750000         4.561250
# 50%           NaN                 NaN        76.500000         5.260500
# 75%           NaN                 NaN       117.250000         6.422000
# max           NaN                 NaN       158.000000         7.587000
#
#         standard error         PIB      family  expect_vida     freedom  \
# ...

# %% [markdown]
# ### G -
#         O valor médio da expectativa de vida é 0.638187
#         O valor mediano da expectativa de vida é 0.705930
#         O TOP da variavel PIB é 1.690420
